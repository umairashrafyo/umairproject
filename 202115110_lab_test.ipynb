# %% [markdown]
# <a href="https://colab.research.google.com/github/umairashrafyo/umairproject/blob/main/202115110_lab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load the dataset
dataset = pd.read_csv("/content/deep learning dataset of lab exam.csv")
# split into input (X) and output (y) variables
X = dataset.iloc[:, 0:2].values
y = dataset.iloc[:, 3].values

# %%
# Out:
#    x  y  z  output label
# 0  2  3  1             1
# 1  1  2  2             1
# 2  2  2  2             1
# 3  3  2  2             1
# 4  5  3  1             0
# 5  6  2  2             0
# 6  7  3  1             0
# 7  8  2  2             0

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-0.92338052,  1.29099445],
#        [-1.33377186, -0.77459667],
#        [-0.92338052, -0.77459667],
#        [-0.51298918, -0.77459667],
#        [ 0.30779351,  1.29099445],
#        [ 0.71818485, -0.77459667],
#        [ 1.12857619,  1.29099445],
#        [ 1.53896753, -0.77459667]])

# %%
from keras import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(4, activation = 'relu',
                     kernel_initializer='random_normal',input_dim=3))
#Second Hidden Layer
model.add(Dense(4, activation = 'relu',
                     kernel_initializer = 'random_normal'))
#Output Layer
model.add(Dense(1,activation='sigmoid',
                     kernel_initializer='random_normal'))

# %%
# compile the keras model
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X,y, batch_size=1, epochs=30)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 1s 2ms/step - loss: 0.6934 - accuracy: 0.3159
# Epoch 2/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.3328
# Epoch 3/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.6265
# Epoch 4/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4939
# Epoch 5/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4003
# Epoch 6/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.0844
# Epoch 7/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.0278
# Epoch 8/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5931
# Epoch 9/30
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.0000e+00
# Epoch 10/30
# ...

# %%
from mpl_toolkits import mplot3d

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax.scatter3D(dataset.iloc[:,1],dataset.iloc[:,2],dataset.iloc[:,3])
fig

# %%
def f(x, y):
    return 4

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
ax.plot_surface(Z, X, Y, alpha=0.2)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
fig
