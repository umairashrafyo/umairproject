# %% [markdown]
# <a href="https://colab.research.google.com/github/umairashrafyo/umairproject/blob/main/202115110_lab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load the dataset, first dataset was created on csv file then loaded on collab python ide
dataset = pd.read_csv("/content/deep learning dataset of lab exam.csv")
# split into input (X) and output (y) variables
X = dataset.iloc[:, 0:3].values
y = dataset.iloc[:, 3].values
X
# Out:
# array([[2, 3, 1],
#        [1, 2, 2],
#        [2, 2, 2],
#        [3, 2, 2],
#        [5, 3, 1],
#        [6, 2, 2],
#        [7, 3, 1],
#        [8, 2, 2]])

# %%
dataset
# Out:
#    x  y  z  output label
# 0  2  3  1             1
# 1  1  2  2             1
# 2  2  2  2             1
# 3  3  2  2             1
# 4  5  3  1             0
# 5  6  2  2             0
# 6  7  3  1             0
# 7  8  2  2             0

# %%
#standardisation od input data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-0.92338052,  1.29099445, -1.29099445],
#        [-1.33377186, -0.77459667,  0.77459667],
#        [-0.92338052, -0.77459667,  0.77459667],
#        [-0.51298918, -0.77459667,  0.77459667],
#        [ 0.30779351,  1.29099445, -1.29099445],
#        [ 0.71818485, -0.77459667,  0.77459667],
#        [ 1.12857619,  1.29099445, -1.29099445],
#        [ 1.53896753, -0.77459667,  0.77459667]])

# %%
from keras import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(4, activation = 'relu',
                     kernel_initializer='random_normal',input_dim=3))
#Second Hidden Layer

model.add(Dense(4, activation = 'relu',
                     kernel_initializer = 'random_normal'))
#3rd hidden layer
model.add(Dense(6, activation = 'relu',
                     kernel_initializer = 'random_normal'))
#Output Layer
model.add(Dense(1,activation='sigmoid',
                     kernel_initializer='random_normal'))

# %%
# compile the keras model
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X,y, batch_size=1, epochs=50)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.6606
# Epoch 2/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6934 - accuracy: 0.4069
# Epoch 3/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5180
# Epoch 4/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.7135
# Epoch 5/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.2180
# Epoch 6/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.6265
# Epoch 7/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.7820
# Epoch 8/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.4228
# Epoch 9/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.2828
# Epoch 10/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.4820
# Epoch 11/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.2828
# Epoch 12/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6926 - accuracy: 0.3791
# Epoch 13/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.5561
# Epoch 14/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6915 - accuracy: 0.5098
# Epoch 15/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6908 - accuracy: 0.6024
# Epoch 16/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.9563
# Epoch 17/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6879 - accuracy: 0.7952
# Epoch 18/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6894 - accuracy: 1.0000
# Epoch 19/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 1.0000
# Epoch 20/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 1.0000
# Epoch 21/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6758 - accuracy: 1.0000
# Epoch 22/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6786 - accuracy: 1.0000
# Epoch 23/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6773 - accuracy: 1.0000
# Epoch 24/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6640 - accuracy: 1.0000
# Epoch 25/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6596 - accuracy: 1.0000
# Epoch 26/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6533 - accuracy: 1.0000
# Epoch 27/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6350 - accuracy: 1.0000
# Epoch 28/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6403 - accuracy: 1.0000
# Epoch 29/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6207 - accuracy: 1.0000
# Epoch 30/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 1.0000
# Epoch 31/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6384 - accuracy: 1.0000
# Epoch 32/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6173 - accuracy: 1.0000
# Epoch 33/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 1.0000
# Epoch 34/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5888 - accuracy: 1.0000
# Epoch 35/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5329 - accuracy: 1.0000
# Epoch 36/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 1.0000
# Epoch 37/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4720 - accuracy: 1.0000
# Epoch 38/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4818 - accuracy: 1.0000
# Epoch 39/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 1.0000
# Epoch 40/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5009 - accuracy: 1.0000
# Epoch 41/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4853 - accuracy: 1.0000
# Epoch 42/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 1.0000
# Epoch 43/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4448 - accuracy: 1.0000
# Epoch 44/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 1.0000
# Epoch 45/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4295 - accuracy: 1.0000
# Epoch 46/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 1.0000
# Epoch 47/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4225 - accuracy: 1.0000
# Epoch 48/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3506 - accuracy: 1.0000
# Epoch 49/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2889 - accuracy: 1.0000
# Epoch 50/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2280 - accuracy: 1.0000

# %%
from mpl_toolkits import mplot3d

# %%
figure = plt.figure()
axis_x = plt.axes(projection='3d')

# %%
axis_x.scatter3D(dataset.iloc[:,0],dataset.iloc[:,1],dataset.iloc[:,2])
figure

# %%
def f(x, y):
    return 4

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
axis_x.plot_surface(Z, X, Y, alpha=0.2)
axis_x.set_xlabel('x')
axis_x.set_ylabel('y')
axis_x.set_zlabel('z')
figure

# %%
#predict the test data "t"
lst= {'x':[1,0],'y':[1,0]
        ,'z':[1,0]}

t=pd.DataFrame(lst)

y_predict=model.predict(t)
y_predict=(y_predict>0.5)
1*y_predict
# Out:
# array([[0],
#        [1]])

# %% [markdown]
#  NEURAL network 2 with 4 layers

# %%
# load the dataset, first dataset was created on csv file then loaded on collab python ide
dataset = pd.read_csv("/content/deep learning dataset of lab exam.csv")
# split into input (X) and output (y) variables
X = dataset.iloc[:, 0:3].values
y = dataset.iloc[:, 3].values
X
# Out:
# array([[2, 3, 1],
#        [1, 2, 2],
#        [2, 2, 2],
#        [3, 2, 2],
#        [5, 3, 1],
#        [6, 2, 2],
#        [7, 3, 1],
#        [8, 2, 2]])

# %%
#standardisation od input data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-0.92338052,  1.29099445, -1.29099445],
#        [-1.33377186, -0.77459667,  0.77459667],
#        [-0.92338052, -0.77459667,  0.77459667],
#        [-0.51298918, -0.77459667,  0.77459667],
#        [ 0.30779351,  1.29099445, -1.29099445],
#        [ 0.71818485, -0.77459667,  0.77459667],
#        [ 1.12857619,  1.29099445, -1.29099445],
#        [ 1.53896753, -0.77459667,  0.77459667]])

# %%
from keras import Sequential
from keras.layers import Dense
model2 = Sequential()
model2.add(Dense(4, activation = 'relu',
                     kernel_initializer='random_normal',input_dim=3))
#Second Hidden Layer

model2.add(Dense(4, activation = 'relu',
                     kernel_initializer = 'random_normal'))
#3rd layer
model2.add(Dense(6, activation = 'relu',
                     kernel_initializer = 'random_normal'))
#Output Layer
model2.add(Dense(1,activation='sigmoid',
                     kernel_initializer='random_normal'))

# %%
# compile the keras model
model2.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

# %%
model2.fit(X,y, batch_size=1, epochs=50)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.7135
# Epoch 2/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.4228
# Epoch 3/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6938 - accuracy: 0.2865
# Epoch 4/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.6394
# Epoch 5/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5505
# Epoch 6/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6928 - accuracy: 0.6209
# Epoch 7/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6928 - accuracy: 0.6265
# Epoch 8/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.6487
# Epoch 9/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.5746
# Epoch 10/50
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.3791
# Epoch 11/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5561
# Epoch 12/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.5505
# Epoch 13/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.7820
# Epoch 14/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.6265
# Epoch 15/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6937 - accuracy: 0.3328
# Epoch 16/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.6050
# Epoch 17/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.2458
# Epoch 18/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5402
# Epoch 19/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6936 - accuracy: 0.2828
# Epoch 20/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4820
# Epoch 21/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5505
# Epoch 22/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6940 - accuracy: 0.2180
# Epoch 23/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4939
# Epoch 24/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.3394
# Epoch 25/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4902
# Epoch 26/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5180
# Epoch 27/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.7320
# Epoch 28/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4717
# Epoch 29/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.6487
# Epoch 30/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.7135
# Epoch 31/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.5561
# Epoch 32/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.4635
# Epoch 33/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6938 - accuracy: 0.2458
# Epoch 34/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.5061
# Epoch 35/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.3606
# Epoch 36/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.4291
# Epoch 37/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.6765
# Epoch 38/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.3384
# Epoch 39/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.3606
# Epoch 40/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.2865
# Epoch 41/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4902
# Epoch 42/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.3235
# Epoch 43/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5550
# Epoch 44/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.6606
# Epoch 45/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.5098
# Epoch 46/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.3394
# Epoch 47/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.3384
# Epoch 48/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.7820
# Epoch 49/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6936 - accuracy: 0.3672
# Epoch 50/50
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4902

# %%
#predict the test data "t"
lst= {'x':[0,0],'y':[4,10]
        ,'z':[4,10]}

t=pd.DataFrame(lst)

t
# Out:
#    x   y   z
# 0  0   4   4
# 1  0  10  10

# %%
y_predict=model.predict(t)
type(y_predict)
y_predict=(y_predict>0.5)
1*y_predict
# Out:
# array([[1],
#        [1]])

# %%
figure = plt.figure()
axis_x = plt.axes(projection='3d')

# %%
axis_x.scatter3D(dataset.iloc[:,0],dataset.iloc[:,1],dataset.iloc[:,2])
figure

# %%
def f(x, y):
    return 4

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, y)

# %%
axis_x.plot_surface(Z, X, Y, alpha=0.2)
axis_x.set_xlabel('x')
axis_x.set_ylabel('y')
axis_x.set_zlabel('z')
figure

# %% [markdown]
# In model2 when we added 3rd layer with 6 neuron and increased epochs to 50 from 30
